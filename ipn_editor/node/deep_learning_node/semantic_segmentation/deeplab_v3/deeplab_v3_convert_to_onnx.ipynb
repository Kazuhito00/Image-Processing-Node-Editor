# %%
# deeplabv3
# https://tfhub.dev/tensorflow/lite-model/deeplabv3/1/default/1
# !wget https://tfhub.dev/tensorflow/lite-model/deeplabv3/1/default/1?lite-format=tflite -O deeplabv3_1_default_1.tflite

# deeplabv3-mobilenetv3-cityscapes
# https://tfhub.dev/sayakpaul/lite-model/deeplabv3-mobilenetv3-cityscapes/1/default/2
# !wget https://tfhub.dev/sayakpaul/lite-model/deeplabv3-mobilenetv3-cityscapes/1/default/2?lite-format=tflite -O deeplabv3-mobilenetv3-cityscapes_1_default_2.tflite

# deeplabv3-xception65
# https://tfhub.dev/sayakpaul/lite-model/deeplabv3-xception65/1/default/2
# !wget https://tfhub.dev/sayakpaul/lite-model/deeplabv3-xception65/1/default/2?lite-format=tflite -O deeplabv3-xception65_1_default_2.tflite

# deeplabv3-xception65-cityscapes
# https://tfhub.dev/sayakpaul/lite-model/deeplabv3-xception65-cityscapes/1/default/2
# !wget https://tfhub.dev/sayakpaul/lite-model/deeplabv3-xception65-cityscapes/1/default/2?lite-format=tflite -O deeplabv3-xception65-cityscapes_1_default_2.tflite

# deeplabv3-xception65-ade20k
# https://tfhub.dev/sayakpaul/lite-model/deeplabv3-xception65-ade20k/1/default/2
# !wget https://tfhub.dev/sayakpaul/lite-model/deeplabv3-xception65-ade20k/1/default/2?lite-format=tflite -O deeplabv3-xception65-ade20k_1_default_2.tflite

# deeplabv3-mobilenetv2
# https://tfhub.dev/sayakpaul/lite-model/deeplabv3-mobilenetv2/1/default/1
# !wget https://tfhub.dev/sayakpaul/lite-model/deeplabv3-mobilenetv2/1/default/1?lite-format=tflite -O deeplabv3-mobilenetv2_1_default_1.tflite

# deeplabv3-mobilenetv2-ade20k
# https://tfhub.dev/sayakpaul/lite-model/deeplabv3-mobilenetv2-ade20k/1/default/2
# !wget https://tfhub.dev/sayakpaul/lite-model/deeplabv3-mobilenetv2-ade20k/1/default/2?lite-format=tflite -O deeplabv3-mobilenetv2-ade20k_1_default_2.tflite
# Out:
# --2022-06-03 01:22:01--  https://tfhub.dev/tensorflow/lite-model/deeplabv3/1/default/1?lite-format=tflite
# Resolving tfhub.dev (tfhub.dev)... 64.233.189.139, 64.233.189.101, 64.233.189.113, ...
# Connecting to tfhub.dev (tfhub.dev)|64.233.189.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/tfhub-lite-models/tensorflow/lite-model/deeplabv3/1/default/1.tflite [following]
# --2022-06-03 01:22:02--  https://storage.googleapis.com/tfhub-lite-models/tensorflow/lite-model/deeplabv3/1/default/1.tflite
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.188.128, 142.250.157.128, 74.125.23.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.188.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2779264 (2.7M) [application/octet-stream]
# Saving to: ‘deeplabv3_1_default_1.tflite’
#
# ...

# %%
# !pip install -U tf2onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 440 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 12.8 MB 52.5 MB/s
# ...
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# ...

# %%
# !python3 -m tf2onnx.convert --tflite deeplabv3_1_default_1.tflite --output deeplabv3_1_default_1.onnx
# !python3 -m tf2onnx.convert --opset=14 --tflite deeplabv3-mobilenetv3-cityscapes_1_default_2.tflite --output deeplabv3-mobilenetv3-cityscapes_1_default_2.onnx
# !python3 -m tf2onnx.convert --tflite deeplabv3-xception65_1_default_2.tflite --output deeplabv3-xception65_1_default_2.onnx
# !python3 -m tf2onnx.convert --tflite deeplabv3-xception65-cityscapes_1_default_2.tflite --output deeplabv3-xception65-cityscapes_1_default_2.onnx
# !python3 -m tf2onnx.convert --tflite deeplabv3-xception65-ade20k_1_default_2.tflite --output deeplabv3-xception65-ade20k_1_default_2.onnx
# !python3 -m tf2onnx.convert --tflite deeplabv3-mobilenetv2_1_default_1.tflite --output deeplabv3-mobilenetv2_1_default_1.onnx
# !python3 -m tf2onnx.convert --tflite deeplabv3-mobilenetv2-ade20k_1_default_2.tflite --output deeplabv3-mobilenetv2-ade20k_1_default_2.onnx
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-06-03 01:22:30,989 - INFO - Using tensorflow=2.8.2, onnx=1.11.0, tf2onnx=1.10.1/a37f29
# 2022-06-03 01:22:30,989 - INFO - Using opset <onnx, 9>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 2022-06-03 01:22:31,294 - INFO - Optimizing ONNX model
# 2022-06-03 01:22:32,153 - INFO - After optimization: Const -21 (133->112), Identity -1 (1->0), Reshape -17 (17->0), Transpose -226 (228->2), Upsample -1 (3->2)
# 2022-06-03 01:22:32,180 - INFO -
# 2022-06-03 01:22:32,180 - INFO - Successfully converted TensorFlow model deeplabv3_1_default_1.tflite to ONNX
# 2022-06-03 01:22:32,180 - INFO - Model inputs: ['sub_7']
# 2022-06-03 01:22:32,180 - INFO - Model outputs: ['ResizeBilinear_3']
# ...
